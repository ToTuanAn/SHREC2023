# %%
WORKDIR = "/home/totuanan/Workplace/SHREC2023/SHREC2023"

# %%
# %cd $WORKDIR
# !pip install .
# Out:
# /home/totuanan/Workplace/SHREC2023/SHREC2023
# Processing /home/totuanan/Workplace/SHREC2023/SHREC2023
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for shrec2023: filename=shrec2023-0.0.1-py3-none-any.whl size=23532 sha256=bc233cd58e56b2f9d02e566f6ea2b91abe3ea72a3858d43a316ccaca784d0acd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-63vvzym7/wheels/f5/1f/57/47ee352a6c80510cf3ee381584bdb9085248a82c4f0a7b0649
# Successfully built shrec2023
# ...
#   Attempting uninstall: shrec2023
#     Found existing installation: shrec2023 0.0.1
#     Uninstalling shrec2023-0.0.1:
#       Successfully uninstalled shrec2023-0.0.1
# ...

# %%
# %cd $WORKDIR
# !python src/train.py -c local_configs/baseline.yml
# Out:
# /home/totuanan/Workplace/SHREC2023/SHREC2023
# /home/totuanan/anaconda3/envs/cvpr_ntl/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libc10_cuda.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Overriding configurating
# Global seed set to 1337
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# ...
